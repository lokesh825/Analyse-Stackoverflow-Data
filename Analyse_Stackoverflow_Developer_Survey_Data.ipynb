# %% [markdown]
# # Task 1

# %% [markdown]
# ### A) Import all the required Libraries

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### B) Access the Dataset as pandas Dataframes,

# %%
df_schema= pd.read_csv('F:/Edugrad/Edugrad Project 1/survey_results_schema.csv')

# %%
df_survey= pd.read_csv('F:/Edugrad/Edugrad Project 1/survey_results_public.csv')
# Out:
# C:\Users\LOKESH ARUN BHIRUD\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### C) Explore the df_schema to see what are different columns available and see their description

# %%
pd.options.display.max_colwidth = 300

# %%
df_schema[:60]
# Out:
#                    Column  \
# 0              Respondent
# 1                   Hobby
# 2              OpenSource
# 3                 Country
# 4                 Student
# 5              Employment
# 6         FormalEducation
# 7          UndergradMajor
# 8             CompanySize
# 9                 DevType
# 10            YearsCoding
# 11        YearsCodingProf
# 12        JobSatisfaction
# 13     CareerSatisfaction
# 14          HopeFiveYears
# 15        JobSearchStatus
# 16             LastNewJob
# 17             AssessJob1
# 18             AssessJob2
# 19             AssessJob3
# 20             AssessJob4
# 21             AssessJob5
# 22             AssessJob6
# 23             AssessJob7
# 24             AssessJob8
# 25             AssessJob9
# 26            AssessJob10
# 27        AssessBenefits1
# 28        AssessBenefits2
# 29        AssessBenefits3
# 30        AssessBenefits4
# 31        AssessBenefits5
# 32        AssessBenefits6
# 33        AssessBenefits7
# ...

# %%
df_schema[60:120]
# Out:
#                           Column  \
# 60             TimeAfterBootcamp
# 61              HackathonReasons
# 62                AgreeDisagree1
# 63                AgreeDisagree2
# 64                AgreeDisagree3
# 65            LanguageWorkedWith
# 66        LanguageDesireNextYear
# 67            DatabaseWorkedWith
# 68        DatabaseDesireNextYear
# 69            PlatformWorkedWith
# 70        PlatformDesireNextYear
# 71           FrameworkWorkedWith
# 72       FrameworkDesireNextYear
# 73                           IDE
# 74               OperatingSystem
# 75                NumberMonitors
# 76                   Methodology
# 77                VersionControl
# 78                   CheckInCode
# 79                     AdBlocker
# 80              AdBlockerDisable
# 81              AdBlockerReasons
# 82             AdsAgreeDisagree1
# 83             AdsAgreeDisagree2
# 84             AdsAgreeDisagree3
# 85                    AdsActions
# 86                AdsPriorities1
# ...

# %%
df_schema[120:]
# Out:
#                 Column  \
# 120             Gender
# 121  SexualOrientation
# 122   EducationParents
# 123      RaceEthnicity
# 124                Age
# 125         Dependents
# 126         MilitaryUS
# 127      SurveyTooLong
# 128         SurveyEasy
#
#                                                                                                                                            QuestionText
# 120  Which of the following do you currently identify as? Please select all that apply. If you prefer not to answer, you may leave this question blank.
# 121  Which of the following do you currently identify as? Please select all that apply. If you prefer not to answer, you may leave this question blank.
# 122          What is the highest level of education received by either of your parents? If you prefer not to answer, you may leave this question blank.
# ...

# %%
#df_survey.describe()

# %% [markdown]
# ### Write 10 different columns which you find interesting in order to analyze the Developers’ Survey Data and support your answer by telling how these column can be used. Your explanation can be in descriptive form or you can take a step ahead and think in terms of Visuals or even some Model.

# %% [markdown]
# To Answer this Question about most intresting 10 fetures in data set is decided by On which Aspect do you want to focus Like:
#
# 1) Developers profile - In which you can find out the most number of developers you have, is their having hobby to code, experience in code(including student life, excluding student(professional)), Type of Developers all over the world or profile, Developers eduction, learning resources etc.
#
# 2) Technology :- Most popular tecnology, library, frameworks and tools etc.
#
# 3) Employment status
#
# 4) Stackoverflow community

# %% [markdown]
# #### Considering Developers Profile Case and Accordingly giving the TOP 10 intresting fetures/columns

# %% [markdown]
# 1. Country:- Maximum no. of developers in the county
# 2. Hobby:- weather they like to code as hobby or not
# 3. OpenSource:- Contribute to OpenSource or not
# 4. Student:- Most no. of the developers are students or not and enroll in any degree full or part-time program
# 5. formalEducation :- Giving the formaleduction of the developers
# 6. UndergradMajor:- belongs to which field like Computer Science, electrical engg. etc
# 7. DevType:- Type of Developer (forntend, backend, datascientiest etc.)
# 8. YearsCoding:- Total no. of coding experience (including student, professional, non-professional experiance)
# 9. YearsCodingProf:- professional experiance in coding
# 10. Age:- Age group of developers
# 11. Gender:- Male or Female

# %%
fig=plt.figure(figsize=(20,20))

Country=df_survey['Country'].value_counts().head(20)
ax6=plt.subplot2grid((4,10),(0,0),colspan=2)
ax6.set_title("Top 20 Survey Respondent Country developers")
ax6.barh(Country.index, Country.values)

hobby=df_survey['Hobby'].value_counts()
ax1=plt.subplot2grid((4,10),(1,0),colspan=2)
ax1.set_title("Coding as hobby")
ax1.bar(hobby.index,hobby.values)

opensource=df_survey['OpenSource'].value_counts()
ax2=plt.subplot2grid((4,10),(2,3), colspan=2)
ax2.set_title("Open Source Contribution Status")
ax2.bar(opensource.index,opensource.values)

student=df_survey['Student'].value_counts()
ax3=plt.subplot2grid((4,10),(2,0), colspan=2)
ax3.set_title("currently enrolled in a formal, degree-granting college or university program")
ax3.bar(student.index,student.values)

formal=df_survey['FormalEducation'].value_counts()
ax4=plt.subplot2grid((4,10),(0,6),colspan=4)
ax4.set_title("formalEducation of Developers")
ax4.barh(formal.index,formal.values)

undergrd=df_survey['UndergradMajor'].value_counts()
ax5=plt.subplot2grid((4,10),(1,6),colspan=4)
ax5.set_title("Major Area of Graduation")
ax5.barh(undergrd.index,undergrd.values)

age=df_survey['Age'].value_counts()
ax7=plt.subplot2grid((4,10),(2,6),colspan=4)
ax7.set_title("Developers Age Groups")
ax7.barh(age.index, age.values)

codingex=df_survey['YearsCoding'].value_counts()
ax8=plt.subplot2grid((4,10),(3,0),colspan=4)
ax8.set_title("Total Coding Experience(in years)")
ax8.barh(codingex.index, codingex.values)

procodingex=df_survey['YearsCodingProf'].value_counts()
ax9=plt.subplot2grid((4,10),(3,5),colspan=5)
ax9.set_title("Professional Coding Experience(in years)")
ax9.barh(procodingex.index, procodingex.values)
# Out:
# <BarContainer object of 11 artists>

# %% [markdown]
# #### The "DevType" feature shows that most of the developer having frontend and Backend backend as Professesnal profile and  some developers are students (specific profile/role)

# %%
'''Top20 developers Role/Profile'''
df_survey['DevType'].value_counts().head(20)
# Out:
# Back-end developer                                                                                          6417
# Full-stack developer                                                                                        6104
# Back-end developer;Front-end developer;Full-stack developer                                                 4460
# Mobile developer                                                                                            3518
# Student                                                                                                     3222
# Back-end developer;Full-stack developer                                                                     3128
# Front-end developer                                                                                         2608
# Front-end developer;Full-stack developer                                                                    1117
# ...

# %% [markdown]
# #### gives the infomation about female , male & others Developers

# %%
df_survey['Gender'].value_counts()
# Out:
# Male                                                                         59458
# Female                                                                        4025
# Non-binary, genderqueer, or gender non-conforming                              284
# Female;Transgender                                                             145
# Male;Non-binary, genderqueer, or gender non-conforming                         128
# Transgender                                                                    105
# Female;Male                                                                     98
# Transgender;Non-binary, genderqueer, or gender non-conforming                   51
# Female;Male;Transgender;Non-binary, genderqueer, or gender non-conforming       50
# Female;Non-binary, genderqueer, or gender non-conforming                        50
# Male;Transgender                                                                29
# ...

# %% [markdown]
# #### Most populer programmig, scripting languages can be obtained using "LanguageWorkedWith" feature

# %%
df_survey['LanguageWorkedWith'].value_counts()
# Out:
# C#;JavaScript;SQL;HTML;CSS                                                                                 1347
# JavaScript;PHP;SQL;HTML;CSS                                                                                1235
# Java                                                                                                       1030
# JavaScript;HTML;CSS                                                                                         881
# C#;JavaScript;SQL;TypeScript;HTML;CSS                                                                       828
#                                                                                                            ...
# Assembly;C;C++;C#;JavaScript;Lua;SQL;VBA;VB.NET;Visual Basic 6;Delphi/Object Pascal;HTML;CSS;Bash/Shell       1
# Go;Groovy;Java;JavaScript;TypeScript;HTML;CSS;Bash/Shell                                                      1
# ...

# %% [markdown]
# ### D) Find out how many users took the survey and how many parameters have been stored corresponding to each user?

# %%
df_survey.shape  #here the total number of users who took the survey is 98855 and the paramerter stored corresponding to each use is 129
# Out:
# (98855, 129)

# %% [markdown]
# ### E) Analyze the df_survey dataframe and see what kind of Data is available, its type, and its values for different users

# %%
df_survey.head(10)   #give the number how many rows you want to see, we can use slicing and tail methods as well
# Out:
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
# 5           8   Yes         No  United Kingdom              No
# 6           9   Yes        Yes   United States              No
# 7          10   Yes        Yes         Nigeria              No
# 8          11   Yes        Yes   United States              No
# 9          16    No        Yes           India              No
#
#            Employment                                         FormalEducation  \
# 0  Employed part-time                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time                Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...

# %%
df_survey.describe()   #gives the count mean, median, max etc. for the numerical columns
# Out:
#           Respondent    AssessJob1    AssessJob2    AssessJob3    AssessJob4  \
# count   98855.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean    50822.971635      6.397089      6.673524      5.906875      4.065791
# std     29321.650410      2.788428      2.531202      2.642734      2.541196
# min         1.000000      1.000000      1.000000      1.000000      1.000000
# 25%     25443.500000      4.000000      5.000000      4.000000      2.000000
# 50%     50823.000000      7.000000      7.000000      6.000000      4.000000
# 75%     76219.500000      9.000000      9.000000      8.000000      6.000000
# max    101592.000000     10.000000     10.000000     10.000000     10.000000
#
#          AssessJob5    AssessJob6    AssessJob7    AssessJob8    AssessJob9  \
# count  66985.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean       3.953243      4.407196      5.673181      4.225200      7.640009
# ...

# %%
df_survey.dtypes #datatype of the columns
# Out:
# Respondent        int64
# Hobby            object
# OpenSource       object
# Country          object
# Student          object
#                   ...
# Age              object
# Dependents       object
# MilitaryUS       object
# SurveyTooLong    object
# SurveyEasy       object
# Length: 129, dtype: object

# %%
df_survey['Country'].value_counts().head(10) #for each columns whose datatype is object we can use the value_counts to analyize the each value corressponding to that column
# Out:
# United States         20309
# India                 13721
# Germany                6459
# United Kingdom         6221
# Canada                 3393
# Russian Federation     2869
# France                 2572
# Brazil                 2505
# Poland                 2122
# Australia              2018
# Name: Country, dtype: int64

# %% [markdown]
# # Task 2 – Distribution along a Single Column

# %% [markdown]
# ### A) What is the data type of ConvertedSalary column? Does it contain categoric or numeric data?

# %%
#about datatype of the "ConvertedSalary"
print('Data type of the ConvertedSalary column is :',df_survey['ConvertedSalary'].dtypes)
print('ConvertedSalary column contains numeric data of type float64')
# Out:
# Data type of the ConvertedSalary column is : float64
# ConvertedSalary column contains numeric data of type float64

# %% [markdown]
# ### B) What does ConvertedSalary column store?

# %%
df_schema=df_schema.set_index('Column')
print('The ConvertedSalary column contains the following information about:- ',df_schema.loc['ConvertedSalary','QuestionText'])
# Out:
# The ConvertedSalary column contains the following information about:-  Salary converted to annual USD salaries using the exchange rate on 2018-01-18, assuming 12 working months and 50 working weeks.

# %% [markdown]
# ### C) Write code to Verify whether the ConvertedSalary column contains any null value or not

# %%
print("ConvertedSalary column contains any null value is a",df_survey['ConvertedSalary'].isnull().any(),"statement.")
print("Number of Null Values in the ConvertedSalary Column is",df_survey['ConvertedSalary'].isnull().sum(),'.')
# Out:
# ConvertedSalary column contains any null value is a True statement.
# Number of Null Values in the ConvertedSalary Column is 51153 .

# %% [markdown]
# ### D) Based on the output of part C), remove the rows containing Null values in a separate Dataframe called df_sal_NonNa

# %%
df_sal_NonNa=pd.DataFrame()
df_sal_NonNa=df_survey
df_sal_NonNa['ConvertedSalary'].dropna(inplace=True)
#print(df_sal_NonNa['ConvertedSalary'])

# %% [markdown]
# ### E) Use seaborn library to plot histogram for non-null values of ConvertedSalary column.

# %% [markdown]
# #### Plot histogram for df_sal_NonNa having bin size as 30 and 500

# %%
fig=plt.figure(figsize=(18,6))
ax1=fig.add_subplot(1,2,1)
ax1.set_title("Histogram with bin size 30")
sns.distplot(df_sal_NonNa['ConvertedSalary'],bins=30,kde=False)
ax2=fig.add_subplot(1,2,2)
ax2.set_title("Histogram with bin size 500")
sns.distplot(df_sal_NonNa['ConvertedSalary'],bins=500,kde=False)

# %% [markdown]
# #### Describe the results plotted in the Histogram

# %% [markdown]
# these histogram shows that there are many developers having 0 - 2,50,000 dollors per years and there are very few developers having annual income  more than 10,00,000 dollors in commpersion to other developers.

# %%
print("0$ - 250000$ there are",(df_sal_NonNa['ConvertedSalary']<=250000).sum(),"developers.")
print("Above 250000$-1000000 there are",(df_sal_NonNa['ConvertedSalary']>250000).sum()-(df_sal_NonNa['ConvertedSalary']>1000000).sum(),"developers.")
print("Above 1000000$ there are",(df_sal_NonNa['ConvertedSalary']>1000000).sum(),"developers.")
# Out:
# 0$ - 250000$ there are 45565 developers.
# Above 250000$-1000000 there are 1743 developers.
# Above 1000000$ there are 394 developers.

# %% [markdown]
# ### F) Create a new Dataframe variable called df_sal_low, to store non-null ConvertedSalary whose value is less than or equal to 250000.
# #### Plot histogram for df_sal_low

# %%
df_sal_low=pd.DataFrame()
df_sal_low['ConvertedSalary']=df_survey['ConvertedSalary'].loc[df_survey['ConvertedSalary'] <= 250000]
#print(df_sal_low)
sns.distplot(df_sal_low['ConvertedSalary'],kde=False)

# %% [markdown]
# #### Describe the results plotted in the Histogram

# %%
print("In the range of 0$ - 250000$ there are",(df_sal_NonNa['ConvertedSalary']<=250000).sum(),"developers.")
# Out:
# In the range of 0$ - 250000$ there are 45565 developers.

# %% [markdown]
# ### G) Plot Salary distribution for both df_sal_NonNa and df_sal_low using a KDE Plot

# %%
plt.figure(figsize=(8,6))
fig=plt.figure(figsize=(18,6))
ax1=fig.add_subplot(1,2,1)
ax1.set_title("KDE plot for all salary range")
sns.kdeplot(df_sal_NonNa['ConvertedSalary'])
ax2=fig.add_subplot(1,2,2)
ax2.set_title("KDE plot for salary <= 250000")
sns.kdeplot(df_sal_low['ConvertedSalary'])

# %% [markdown]
# #### Describe the results of the KDE plot

# %% [markdown]
# kernel density estimation is(sum of all the probability in each cases) 1 in both the cases but the difference is that the dataframe df_sal_NonNa is having each and every developers salary values with is not Null so that distribution of the probabitity accordingly.
#
# And in Dataframe df_sal_low is having only those developers salary values which is having less than or equal to 250000$ so this distribution of the probability accordingly.

# %% [markdown]
# # Task 3 - Distribution with Multiple Columns

# %% [markdown]
# ### A) For this task we will plot stripplot and see the distribution of Salary and countries

# %%
plt.figure(figsize=(22,10))
plt.xticks(rotation=90)
ax = sns.stripplot(x="Country", y="ConvertedSalary", data=df_survey)

# %% [markdown]
# #### What did you see? Which country has the highest Salary and which falls in the lowest salary segment?

# %% [markdown]
# 1) United Kingdom has the highest Salary.(in the give graph left hand side countries is having highest Salary.)
#
# 2) Brunel, Democratic etc. has the lowest Salary.(in the given graph right hand side countries is having lowest Salary.)

# %% [markdown]
# ### B) The plot in section A is not very clear in order to make predictions. So we need to select some countries. Lets take the top 5 countries from where the users’ belong to see their salary distribution. Again plot the stripplot using convertedsalary for the top 5 countries.

# %%
stripplot=df_sal_NonNa[['Country','ConvertedSalary']].dropna()
stripplot5=stripplot.groupby('Country').sum()
stripplot5=stripplot5.sort_values(['ConvertedSalary'],ascending=False)
stripplot5=stripplot5.head() #top 5 countries in terms to total salary
stripplot5
# Out:
#                 ConvertedSalary
# Country
# United States      1.998260e+09
# United Kingdom     4.864550e+08
# Germany            3.088018e+08
# Canada             2.000735e+08
# Australia          1.494160e+08

# %% [markdown]
# #### Top 5 Countries in terms of Salary

# %%
stripdata=pd.DataFrame()
for i in list(stripplot5.index):
    stripdata=stripdata.append(stripplot[stripplot['Country']==i])
ax = sns.stripplot(x="Country", y="ConvertedSalary", data=stripdata)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text major ticklabel objects>)

# %% [markdown]
# #### Which are the countries from where most developers who took the survey belong? (based on Number of developers participated in the survey )

# %%
Country=df_survey['Country'].value_counts().head(5) #top5 contonry whose developers maximum participated in the survey(in terms of count)
stripdata1=pd.DataFrame()
for i in list(Country.index):
    stripdata1=stripdata1.append(stripplot[stripplot['Country']==i])
ax = sns.stripplot(x="Country", y="ConvertedSalary", data=stripdata1,jitter=1)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text major ticklabel objects>)

# %% [markdown]
# #### Based on stripplot describe the distribution of Salary among these countries like which country has developers in highest range, which is in lowest range, which country it is distributed evenly.

# %% [markdown]
# #### bottom 5 countries in terms to total salary

# %%
stripplot=df_survey[['Country','ConvertedSalary']].dropna()
stripplot5=stripplot.groupby('Country').sum()
stripplot5=stripplot5.sort_values(['ConvertedSalary'])
stripplot5=stripplot5.head() #bottom 5 countries in terms to total salary
stripplot5
# Out:
#                ConvertedSalary
# Country
# Monaco                     0.0
# Dominica                1000.0
# Zambia                  1824.0
# Eritrea                 3000.0
# Côte d'Ivoire           3672.0

# %%
stripdata=pd.DataFrame()
for i in list(stripplot5.index):
    stripdata=stripdata.append(stripplot[stripplot['Country']==i])
ax = sns.stripplot(x="Country", y="ConvertedSalary", data=stripdata)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text major ticklabel objects>)

# %% [markdown]
# #### Bottom 5 Country in terms of survey taken by the country developers

# %%
Country=df_survey['Country'].value_counts().tail(20)#bottom20 contonry whose developers maximum participated in the survey(in terms of count)
#print(Country)
stripdata2=pd.DataFrame()
for i in list(Country.index):
    stripdata2=stripdata2.append(stripplot[stripplot['Country']==i])
ax = sns.stripplot(x="Country", y="ConvertedSalary", data=stripdata2)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text major ticklabel objects>)

# %% [markdown]
# #### Based on stripplot describe the distribution of Salary among these countries like which country has developers in highest range, which is in lowest range, which country it is distributed evenly.

# %% [markdown]
# based on the above analysis on the basis of stripplots we can say that "US, UK,Germany" are the countries who has developers in higest range and Djibouti, Belize, Nauru, Saint Lucia, Grenada countrie etc. who has lowest range and India, canada, australia etc. are the countries those are distributed some how evenly.

# %% [markdown]
# ### C) Plot the swarmplot for the top 5 countries based on no. of developers for the Salary. (refer above section B for Data)  These swarmplot are on sample data

# %%
import random
swarmplot=df_survey[['Country','ConvertedSalary']].dropna()
Country1=df_survey['Country'].value_counts().head(5)#top5 contonry whose developers maximum participated in the survey(in terms of count)
swarmdata=pd.DataFrame()
for i in list(Country1.index):
    swarmdata=swarmdata.append(swarmplot[swarmplot['Country']==i])
swarmdata=swarmdata.sample(1000)

# %%
plt.figure(figsize=(22,10))
plt.xticks(rotation=90)
ax = sns.swarmplot(x="Country", y="ConvertedSalary", data=swarmdata)

# %% [markdown]
# #### Compare the result of swarmplot with the result of stripplot (in section B). What is the benefit of one over the other.

# %% [markdown]
# This function is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, but it does not scale well to large numbers of observations. This style of plot is sometimes called a “beeswarm”.

# %% [markdown]
# # Task 4 – Impact of Education on Salary

# %% [markdown]
# #### For this we will use df_sal_NonNa dataframe and FormalEducation and ConvertedSalary columns
# ### A) See how Formal Education is related to Salary by displaying in the form of swarmplot

# %%
plt.figure(figsize=(22,10))
swarmplotsample=df_sal_NonNa.sample(10000)
plt.xticks(rotation=90)
ax = sns.swarmplot(x="FormalEducation", y="ConvertedSalary", data=swarmplotsample)
# Out:
# C:\Users\LOKESH ARUN BHIRUD\Anaconda3\lib\site-packages\seaborn\categorical.py:1324: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\LOKESH ARUN BHIRUD\Anaconda3\lib\site-packages\seaborn\categorical.py:1328: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %% [markdown]
# #### Describe the result of swarmplot for FormalEducation and ConvertedSalary columns. Formal Education of the developers who fetches salary in highest range, which is in in lowest range, Salary distribution of which education is distributed evenly.

# %% [markdown]
# 1. According to the graph ploted developers who have Bachelor's and Master's degree as a formal education having much highest range of Salary.
# 2. Having no fomal eduction, secondary education, primay eduction having lowest range.
# 3. Some College/university study without earning a degree, bachelor's , Master's degree as a formal education is distributed evenly.

# %% [markdown]
# ### B) Next add Employment as third or the hue parameter to see how Formal Education is scattered in terms of Employment Type

# %%
plt.figure(figsize=(22,10))
plt.xticks(rotation=90)
ax = sns.swarmplot(x="FormalEducation", y="ConvertedSalary", data=swarmplotsample, hue='Employment')

# %% [markdown]
# #### Describe the result.
# #### What is the impact of adding hue on the swarmplot?

# %% [markdown]
# 1) As we can see that most of the developers having the full-time employed and get lowest to highest range of salary.
#
# 2) In other five catagory most of the developers having lowest range of salary.
#
# 3) Adding hue on the swarmplot gives more inside of the data like in this example it more catagorized my data and showing the developers salary relation with their employment status.

# %% [markdown]
# # Task 5 – Boxplot

# %% [markdown]
# ### Lets now create a boxplot using 'Formal Education and 'Converted Salary'

# %%
plt.figure(figsize=(22,10))
plt.xticks(rotation=90)
sns.boxplot(x=df_sal_NonNa['FormalEducation'],y=df_sal_NonNa['ConvertedSalary'])

# %% [markdown]
# #### What could you make out from the Boxplot, describe it in your words

# %% [markdown]
# Form the above Boxplots it gives me insides about the data:
#
# 1.) About the minimum salary of the developers having different formaleductaion
#
# 2.) Average Salary of the developers having different formaleducation
#
# 3.) Maximum Salary corresponding to the each and every formaleducation
#
# And gives me the infomation about outliers in the dataset.
# In some cases it may not be the outliers but in general cases we assuming these as a outliers.

# %% [markdown]
# # Task 6 – Pie Chart

# %% [markdown]
# ### A) Create a Pie chart to display the distribution of developers based on their Formal Education
# #### Display their percentages on the Pie-Chart
# #### The respective Formal Education should be displayed outside the circle
# #### The title of the graph should be ‘Classification of Developers by their Formal Education’

# %%
Formaleducation=pd.DataFrame()
Formaleducation=df_survey['FormalEducation'].value_counts()
Formaleducation
# Out:
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              43659
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           21396
# Some college/university study without earning a degree                                11710
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     8951
# Associate degree                                                                       2970
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              2214
# Primary/elementary school                                                              1656
# Professional degree (JD, MD, etc.)                                                     1447
# I never completed any formal education                                                  700
# Name: FormalEducation, dtype: int64

# %%
#plt.axis('equal')
fig=plt.figure(figsize=(12,12))
labels = Formaleducation.index
sizes = Formaleducation.values
plt.pie(sizes, labels=labels,
        autopct='%1.1f%%', shadow=True, startangle=150)
plt.legend(labels, loc="best")
plt.title('Classification of Developers by their Formal Education')
# Out:
# Text(0.5, 1.0, 'Classification of Developers by their Formal Education')

# %% [markdown]
# ### B) Create the same Piechart as in Section A) with the following changes
# #### Explode the three segments with lowest values
# #### Pass in a custom set of colors for different segments

# %%
fig=plt.figure(figsize=(12,12))
labels = Formaleducation.index
sizes = Formaleducation.values
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','pink','brown','green']
explode = (0, 0, 0, 0, 0, 0, 0.2, 0.5, 0.9)  
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.legend(labels, loc="best")

# %% [markdown]
# -------
